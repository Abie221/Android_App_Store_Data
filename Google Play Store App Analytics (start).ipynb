# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
df_apps.sample(5)
# Out:
#                                                     App          Category  \
# 840                            Learn Quran with Elif Ba            FAMILY
# 7195                                  Funny Quotes Free     ENTERTAINMENT
# 7367                          Super Jim Jump - pixel 3d              GAME
# 5584         Gay Sugar Daddy Dating & Hookup – Sudy Gay            DATING
# 2802  Ultimate Public Campgrounds (Over 37,100 in US...  TRAVEL_AND_LOCAL
#
#       Rating  Reviews  Size_MBs   Installs  Type  Price Content_Rating  \
# 840      NaN        3     12.00        100  Paid  $1.49       Everyone
# 7195    4.20    23666      3.60  1,000,000  Free      0           Teen
# 7367    4.50    10393     18.00  1,000,000  Free      0       Everyone
# 5584    4.10     2212     41.00    100,000  Free      0     Mature 17+
# 2802    4.70      213      6.10      5,000  Paid  $3.99       Everyone
#
#               Genres    Last_Updated   Android_Ver
# 840        Education   March 3, 2017    2.3 and up
# 7195   Entertainment     May 4, 2018    4.0 and up
# 7367          Arcade   July 11, 2018    4.0 and up
# 5584          Dating   June 20, 2018  4.0.3 and up
# 2802  Travel & Local  August 5, 2018    4.4 and up

# %%
df_apps
# Out:
#                                                 App         Category  Rating  \
# 0                           Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                        Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2      Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                         Command & Conquer: Rivals           FAMILY     NaN
# 4                                        CX Network         BUSINESS     NaN
# ...                                             ...              ...     ...
# 10836                                Subway Surfers             GAME    4.50
# 10837                                Subway Surfers             GAME    4.50
# 10838                                Subway Surfers             GAME    4.50
# 10839                                Subway Surfers             GAME    4.50
# 10840                                Subway Surfers             GAME    4.50
#
#         Reviews  Size_MBs       Installs  Type   Price Content_Rating  \
# 0             0      8.70              0  Paid  $13.99           Teen
# 1             0     33.00              0  Paid   $2.99       Everyone
# 2             0      5.50              0  Paid   $1.49       Everyone
# 3             0     19.00              0   NaN       0   Everyone 10+
# 4             0     10.00              0  Free       0       Everyone
# ...         ...       ...            ...   ...     ...            ...
# 10836  27723193     76.00  1,000,000,000  Free       0   Everyone 10+
# 10837  27724094     76.00  1,000,000,000  Free       0   Everyone 10+
# 10838  27725352     76.00  1,000,000,000  Free       0   Everyone 10+
# 10839  27725352     76.00  1,000,000,000  Free       0   Everyone 10+
# 10840  27711703     76.00  1,000,000,000  Free       0   Everyone 10+
#
#                 Genres    Last_Updated         Android_Ver
# 0               Social   July 28, 2017          4.1 and up
# 1            Education  April 15, 2016          3.0 and up
# 2      Personalization   July 11, 2018          4.2 and up
# 3             Strategy   June 28, 2018  Varies with device
# 4             Business  August 6, 2018          4.1 and up
# ...                ...             ...                 ...
# 10836           Arcade   July 12, 2018          4.1 and up
# 10837           Arcade   July 12, 2018          4.1 and up
# 10838           Arcade   July 12, 2018          4.1 and up
# 10839           Arcade   July 12, 2018          4.1 and up
# 10840           Arcade   July 12, 2018          4.1 and up
#
# [10841 rows x 12 columns]

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps = df_apps.drop('Last_Updated', axis=1)
df_apps
# Out:
#                                                 App         Category  Rating  \
# 0                           Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                        Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2      Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                         Command & Conquer: Rivals           FAMILY     NaN
# 4                                        CX Network         BUSINESS     NaN
# ...                                             ...              ...     ...
# 10836                                Subway Surfers             GAME    4.50
# 10837                                Subway Surfers             GAME    4.50
# 10838                                Subway Surfers             GAME    4.50
# 10839                                Subway Surfers             GAME    4.50
# 10840                                Subway Surfers             GAME    4.50
#
#         Reviews  Size_MBs       Installs  Type   Price Content_Rating  \
# 0             0      8.70              0  Paid  $13.99           Teen
# 1             0     33.00              0  Paid   $2.99       Everyone
# 2             0      5.50              0  Paid   $1.49       Everyone
# 3             0     19.00              0   NaN       0   Everyone 10+
# 4             0     10.00              0  Free       0       Everyone
# ...         ...       ...            ...   ...     ...            ...
# 10836  27723193     76.00  1,000,000,000  Free       0   Everyone 10+
# 10837  27724094     76.00  1,000,000,000  Free       0   Everyone 10+
# 10838  27725352     76.00  1,000,000,000  Free       0   Everyone 10+
# 10839  27725352     76.00  1,000,000,000  Free       0   Everyone 10+
# 10840  27711703     76.00  1,000,000,000  Free       0   Everyone 10+
#
#                 Genres         Android_Ver
# 0               Social          4.1 and up
# 1            Education          3.0 and up
# 2      Personalization          4.2 and up
# 3             Strategy  Varies with device
# 4             Business          4.1 and up
# ...                ...                 ...
# 10836           Arcade          4.1 and up
# 10837           Arcade          4.1 and up
# 10838           Arcade          4.1 and up
# 10839           Arcade          4.1 and up
# 10840           Arcade          4.1 and up
#
# [10841 rows x 11 columns]

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size_MBs             0
# Installs             0
# Type                 1
# Price                0
# Content_Rating       0
# Genres               0
# Android_Ver          2
# dtype: int64

# %%
df_apps_clean = df_apps.dropna()
df_apps_clean
# Out:
#                                                    App Category  Rating  \
# 21                                 KBA-EZ Health Guide  MEDICAL    5.00
# 28                                            Ra Ga Ba     GAME    5.00
# 47                                             Mu.F.O.     GAME    5.00
# 82                                    Brick Breaker BR     GAME    5.00
# 99     Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00
# ...                                                ...      ...     ...
# 10836                                   Subway Surfers     GAME    4.50
# 10837                                   Subway Surfers     GAME    4.50
# 10838                                   Subway Surfers     GAME    4.50
# 10839                                   Subway Surfers     GAME    4.50
# 10840                                   Subway Surfers     GAME    4.50
#
#         Reviews  Size_MBs       Installs  Type  Price Content_Rating   Genres  \
# 21            4     25.00              1  Free      0       Everyone  Medical
# 28            2     20.00              1  Paid  $1.49       Everyone   Arcade
# 47            2     16.00              1  Paid  $0.99       Everyone   Arcade
# 82            7     19.00              5  Free      0       Everyone   Arcade
# 99            1      4.60              5  Free      0       Everyone  Medical
# ...         ...       ...            ...   ...    ...            ...      ...
# 10836  27723193     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
# 10837  27724094     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
# 10838  27725352     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
# 10839  27725352     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
# 10840  27711703     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
#
#         Android_Ver
# 21     4.0.3 and up
# 28       2.3 and up
# 47       2.3 and up
# 82       4.1 and up
# 99       4.0 and up
# ...             ...
# 10836    4.1 and up
# 10837    4.1 and up
# 10838    4.1 and up
# 10839    4.1 and up
# 10840    4.1 and up
#
# [9365 rows x 11 columns]

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps_clean.duplicated().sum()
# Out:
# 476

# %%
df_apps_clean.drop_duplicates()
# Out:
#                                                    App Category  Rating  \
# 21                                 KBA-EZ Health Guide  MEDICAL    5.00
# 28                                            Ra Ga Ba     GAME    5.00
# 47                                             Mu.F.O.     GAME    5.00
# 82                                    Brick Breaker BR     GAME    5.00
# 99     Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00
# ...                                                ...      ...     ...
# 10835                                   Subway Surfers     GAME    4.50
# 10836                                   Subway Surfers     GAME    4.50
# 10837                                   Subway Surfers     GAME    4.50
# 10838                                   Subway Surfers     GAME    4.50
# 10840                                   Subway Surfers     GAME    4.50
#
#         Reviews  Size_MBs       Installs  Type  Price Content_Rating   Genres  \
# 21            4     25.00              1  Free      0       Everyone  Medical
# 28            2     20.00              1  Paid  $1.49       Everyone   Arcade
# 47            2     16.00              1  Paid  $0.99       Everyone   Arcade
# 82            7     19.00              5  Free      0       Everyone   Arcade
# 99            1      4.60              5  Free      0       Everyone  Medical
# ...         ...       ...            ...   ...    ...            ...      ...
# 10835  27722264     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
# 10836  27723193     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
# 10837  27724094     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
# 10838  27725352     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
# 10840  27711703     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
#
#         Android_Ver
# 21     4.0.3 and up
# 28       2.3 and up
# 47       2.3 and up
# 82       4.1 and up
# 99       4.0 and up
# ...             ...
# 10835    4.1 and up
# 10836    4.1 and up
# 10837    4.1 and up
# 10838    4.1 and up
# 10840    4.1 and up
#
# [8889 rows x 11 columns]

# %%
df_apps_clean = df_apps_clean.drop_duplicates(subset=['App', 'Type', 'Rating'])
df_apps_clean
# Out:
#                                                    App            Category  \
# 21                                 KBA-EZ Health Guide             MEDICAL
# 28                                            Ra Ga Ba                GAME
# 47                                             Mu.F.O.                GAME
# 82                                    Brick Breaker BR                GAME
# 99     Anatomy & Physiology Vocabulary Exam Review App             MEDICAL
# ...                                                ...                 ...
# 10824                                     Google Drive        PRODUCTIVITY
# 10828                                          YouTube       VIDEO_PLAYERS
# 10829                          Google Play Movies & TV       VIDEO_PLAYERS
# 10831                                      Google News  NEWS_AND_MAGAZINES
# 10835                                   Subway Surfers                GAME
#
#        Rating   Reviews  Size_MBs       Installs  Type  Price Content_Rating  \
# 21       5.00         4     25.00              1  Free      0       Everyone
# 28       5.00         2     20.00              1  Paid  $1.49       Everyone
# 47       5.00         2     16.00              1  Paid  $0.99       Everyone
# 82       5.00         7     19.00              5  Free      0       Everyone
# 99       5.00         1      4.60              5  Free      0       Everyone
# ...       ...       ...       ...            ...   ...    ...            ...
# 10824    4.40   2731171      4.00  1,000,000,000  Free      0       Everyone
# 10828    4.30  25655305      4.65  1,000,000,000  Free      0           Teen
# 10829    3.70    906384      4.65  1,000,000,000  Free      0           Teen
# 10831    3.90    877635     13.00  1,000,000,000  Free      0           Teen
# 10835    4.50  27722264     76.00  1,000,000,000  Free      0   Everyone 10+
#
#                         Genres         Android_Ver
# 21                     Medical        4.0.3 and up
# 28                      Arcade          2.3 and up
# 47                      Arcade          2.3 and up
# 82                      Arcade          4.1 and up
# 99                     Medical          4.0 and up
# ...                        ...                 ...
# 10824             Productivity  Varies with device
# 10828  Video Players & Editors  Varies with device
# 10829  Video Players & Editors  Varies with device
# 10831         News & Magazines          4.4 and up
# 10835                   Arcade          4.1 and up
#
# [8212 rows x 11 columns]

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_clean.sort_values('Rating', ascending=False).head()
# Out:
#                                 App            Category  Rating  Reviews  \
# 21              KBA-EZ Health Guide             MEDICAL    5.00        4
# 1019  Startupticker.ch News, Events  NEWS_AND_MAGAZINES    5.00        4
# 1060      Free coupons and vouchers             FINANCE    5.00        4
# 1906                  Safe Santa Fe              FAMILY    5.00        2
# 1051                      EF Events              EVENTS    5.00        7
#
#       Size_MBs Installs  Type Price Content_Rating            Genres  \
# 21       25.00        1  Free     0       Everyone           Medical
# 1019     10.00      100  Free     0       Everyone  News & Magazines
# 1060      5.90      100  Free     0       Everyone           Finance
# 1906     12.00    1,000  Free     0       Everyone         Education
# 1051      4.40      100  Free     0           Teen            Events
#
#              Android_Ver
# 21          4.0.3 and up
# 1019          4.4 and up
# 1060          4.4 and up
# 1906          4.0 and up
# 1051  Varies with device

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_clean.sort_values('Size_MBs', ascending=False).head()
# Out:
#                                   App   Category  Rating  Reviews  Size_MBs  \
# 7926                        Post Bank    FINANCE    4.50    60449    100.00
# 9942   Talking Babsy Baby: Baby Games  LIFESTYLE    4.00   140995    100.00
# 10295                 SimCity BuildIt     FAMILY    4.50  4218587    100.00
# 8719       Draft Simulator for FUT 18     SPORTS    4.60   162933    100.00
# 10687          Hungry Shark Evolution       GAME    4.50  6074334    100.00
#
#           Installs  Type Price Content_Rating                  Genres  \
# 7926     1,000,000  Free     0       Everyone                 Finance
# 9942    10,000,000  Free     0       Everyone  Lifestyle;Pretend Play
# 10295   50,000,000  Free     0   Everyone 10+              Simulation
# 8719     5,000,000  Free     0       Everyone                  Sports
# 10687  100,000,000  Free     0           Teen                  Arcade
#
#       Android_Ver
# 7926   4.0 and up
# 9942   4.0 and up
# 10295  4.0 and up
# 8719   4.1 and up
# 10687  4.1 and up

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_clean.sort_values('Reviews', ascending=False).head()
# Out:
#                                             App       Category  Rating  \
# 10805                                  Facebook         SOCIAL    4.10
# 10785                        WhatsApp Messenger  COMMUNICATION    4.40
# 10806                                 Instagram         SOCIAL    4.50
# 10784  Messenger – Text and Video Chat for Free  COMMUNICATION    4.00
# 10650                            Clash of Clans           GAME    4.60
#
#         Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805  78158306      5.30  1,000,000,000  Free     0           Teen
# 10785  69119316      3.50  1,000,000,000  Free     0       Everyone
# 10806  66577313      5.30  1,000,000,000  Free     0           Teen
# 10784  56642847      3.50  1,000,000,000  Free     0       Everyone
# 10650  44891723     98.00    100,000,000  Free     0   Everyone 10+
#
#               Genres         Android_Ver
# 10805         Social  Varies with device
# 10785  Communication  Varies with device
# 10806         Social  Varies with device
# 10784  Communication  Varies with device
# 10650       Strategy          4.1 and up

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_apps_clean.Content_Rating.value_counts()
ratings
# Out:
# Content_Rating
# Everyone           6634
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
fig = px.pie(labels=ratings.index, values=ratings.values, title='Content Rating', names=ratings.index, hole=0.6)

fig.update_traces(textposition='outside', textinfo='percent+label')
fig.show()

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps_clean.Installs.describe()
# Out:
# count          8212
# unique           19
# top       1,000,000
# freq           1418
# Name: Installs, dtype: object

# %%
df_apps_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
#                 App
# Installs
# 1                 3
# 1,000           697
# 1,000,000      1418
# 1,000,000,000    20
# 10               69
# 10,000          987
# 10,000,000      939
# 100             303
# 100,000        1098
# 100,000,000     189
# 5                 9
# 5,000           425
# 5,000,000       611
# 50               56
# 50,000          457
# 50,000,000      204
# 500             199
# 500,000         504
# 500,000,000      24

# %%
df_apps_clean.Installs = df_apps_clean.Installs.astype(str).str.replace(',', "")
# Out:
# /var/folders/pm/947130td48b2yff02y1061940000gn/T/ipykernel_68708/521985444.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_apps_clean.Installs = pd.to_numeric(df_apps_clean.Installs)
df_apps_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
# /var/folders/pm/947130td48b2yff02y1061940000gn/T/ipykernel_68708/3515150505.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         697
# 5000         425
# 10000        987
# 50000        457
# 100000      1098
# 500000       504
# 1000000     1418
# 5000000      611
# 10000000     939
# 50000000     204
# 100000000    189
# 500000000     24
# 1000000000    20

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_clean
# Out:
#                                                    App            Category  \
# 21                                 KBA-EZ Health Guide             MEDICAL
# 28                                            Ra Ga Ba                GAME
# 47                                             Mu.F.O.                GAME
# 82                                    Brick Breaker BR                GAME
# 99     Anatomy & Physiology Vocabulary Exam Review App             MEDICAL
# ...                                                ...                 ...
# 10824                                     Google Drive        PRODUCTIVITY
# 10828                                          YouTube       VIDEO_PLAYERS
# 10829                          Google Play Movies & TV       VIDEO_PLAYERS
# 10831                                      Google News  NEWS_AND_MAGAZINES
# 10835                                   Subway Surfers                GAME
#
#        Rating   Reviews  Size_MBs    Installs  Type  Price Content_Rating  \
# 21       5.00         4     25.00           1  Free      0       Everyone
# 28       5.00         2     20.00           1  Paid  $1.49       Everyone
# 47       5.00         2     16.00           1  Paid  $0.99       Everyone
# 82       5.00         7     19.00           5  Free      0       Everyone
# 99       5.00         1      4.60           5  Free      0       Everyone
# ...       ...       ...       ...         ...   ...    ...            ...
# 10824    4.40   2731171      4.00  1000000000  Free      0       Everyone
# 10828    4.30  25655305      4.65  1000000000  Free      0           Teen
# 10829    3.70    906384      4.65  1000000000  Free      0           Teen
# 10831    3.90    877635     13.00  1000000000  Free      0           Teen
# 10835    4.50  27722264     76.00  1000000000  Free      0   Everyone 10+
#
#                         Genres         Android_Ver
# 21                     Medical        4.0.3 and up
# 28                      Arcade          2.3 and up
# 47                      Arcade          2.3 and up
# 82                      Arcade          4.1 and up
# 99                     Medical          4.0 and up
# ...                        ...                 ...
# 10824             Productivity  Varies with device
# 10828  Video Players & Editors  Varies with device
# 10829  Video Players & Editors  Varies with device
# 10831         News & Magazines          4.4 and up
# 10835                   Arcade          4.1 and up
#
# [8212 rows x 11 columns]

# %%
df_apps_clean.sort_values('Price', ascending=True).head(20)
# Out:
#                                         App             Category  Rating  \
# 3321                EU Flags Live Wallpaper      PERSONALIZATION    4.30
# 798            B-52 Spirits of Glory Deluxe                 GAME    4.30
# 2499  CE Map - Interactive Conan Exiles Map  MAPS_AND_NAVIGATION    4.50
# 4975              ZOOKEEPER DX TouchEdition               FAMILY    4.20
# 845                         P-Home for KLWP      PERSONALIZATION    5.00
# 898                   Ice Crush 10.000 B.C.               FAMILY    4.40
# 2369               Blood Pressure Companion              MEDICAL    4.20
# 3016               palmPEDi: Pediatric Tape              MEDICAL    4.60
# 3017                       Droid PRoCon BF3                TOOLS    3.50
# 3021             FL Racing Manager 2015 Pro               SPORTS    4.40
# 1021                            CA Speakers            LIFESTYLE    5.00
# 2320            Lock 'n' Roll Pro - Ad Free                 GAME    4.60
# 2313                               FAV KWGT      PERSONALIZATION    4.90
# 1068                  Watch Face Swiss AJ-6      PERSONALIZATION    4.10
# 1116                   All-in-One Mahjong 3               FAMILY    4.40
# 8825                          Hitman Sniper                 GAME    4.60
# 3649         Jurassic Life: T Rex Simulator               FAMILY    4.20
# 2220         Wolf of the BF:Commando MOBILE                 GAME    3.40
# 2502                    Watch Face BW Inter      PERSONALIZATION    3.10
# 4084                Neon Glow C - Icon Pack      PERSONALIZATION    4.80
#
#       Reviews  Size_MBs  Installs  Type  Price Content_Rating  \
# 3321      444     12.00     10000  Paid  $0.99       Everyone
# 798        12     29.00       100  Paid  $0.99       Everyone
# 2499       62      1.60      1000  Paid  $0.99       Everyone
# 4975     3195      4.60    100000  Paid  $0.99       Everyone
# 845         4     12.00       100  Paid  $0.99       Everyone
# 898        31      4.20       100  Paid  $0.99       Everyone
# 2369      178      4.80      1000  Paid  $0.99       Everyone
# 3016       66      2.60      5000  Paid  $0.99       Everyone
# 3017      412      2.60      5000  Paid  $0.99       Everyone
# 3021      656     22.00      5000  Paid  $0.99       Everyone
# 1021       12      1.20       100  Paid  $0.99           Teen
# 2320      169     13.00      1000  Paid  $0.99       Everyone
# 2313       88     66.00      1000  Paid  $0.99       Everyone
# 1068       21      3.60       100  Paid  $0.99       Everyone
# 1116       38     16.00       100  Paid  $0.99       Everyone
# 8825   408292     29.00  10000000  Paid  $0.99     Mature 17+
# 3649     1088     35.00     10000  Paid  $0.99   Everyone 10+
# 2220       32     27.00      1000  Paid  $0.99   Everyone 10+
# 2502      112      8.80      1000  Paid  $0.99       Everyone
# 4084      557     74.00     10000  Paid  $0.99       Everyone
#
#                  Genres   Android_Ver
# 3321    Personalization    2.1 and up
# 798              Arcade    2.3 and up
# 2499  Maps & Navigation    4.0 and up
# 4975             Puzzle    2.1 and up
# 845     Personalization    5.0 and up
# 898              Casual    2.0 and up
# 2369            Medical    4.1 and up
# 3016            Medical    3.2 and up
# 3017              Tools    3.0 and up
# 3021             Sports    3.0 and up
# 1021          Lifestyle    3.0 and up
# 2320               Card  2.3.3 and up
# 2313    Personalization    5.0 and up
# 1068    Personalization    4.3 and up
# 1116  Board;Brain Games    4.0 and up
# 8825             Action    4.1 and up
# 3649         Simulation  2.0.1 and up
# 2220             Arcade    4.0 and up
# 2502    Personalization    4.3 and up
# 4084    Personalization  4.0.3 and up

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df_apps_clean.Price = df_apps_clean.Price.astype(str).str.replace('$', "")
df_apps_clean.Price = pd.to_numeric(df_apps_clean.Price)
df_apps_clean.Price.describe()
# Out:
# /var/folders/pm/947130td48b2yff02y1061940000gn/T/ipykernel_68708/3238054781.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/pm/947130td48b2yff02y1061940000gn/T/ipykernel_68708/3238054781.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# count   8,212.00
# mean        1.04
# std        16.84
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max       400.00
# Name: Price, dtype: float64

# %%
df_apps_clean = df_apps_clean[df_apps_clean['Price'] < 250]
df_apps_clean
# Out:
#                                                    App            Category  \
# 21                                 KBA-EZ Health Guide             MEDICAL
# 28                                            Ra Ga Ba                GAME
# 47                                             Mu.F.O.                GAME
# 82                                    Brick Breaker BR                GAME
# 99     Anatomy & Physiology Vocabulary Exam Review App             MEDICAL
# ...                                                ...                 ...
# 10824                                     Google Drive        PRODUCTIVITY
# 10828                                          YouTube       VIDEO_PLAYERS
# 10829                          Google Play Movies & TV       VIDEO_PLAYERS
# 10831                                      Google News  NEWS_AND_MAGAZINES
# 10835                                   Subway Surfers                GAME
#
#        Rating   Reviews  Size_MBs    Installs  Type  Price Content_Rating  \
# 21       5.00         4     25.00           1  Free   0.00       Everyone
# 28       5.00         2     20.00           1  Paid   1.49       Everyone
# 47       5.00         2     16.00           1  Paid   0.99       Everyone
# 82       5.00         7     19.00           5  Free   0.00       Everyone
# 99       5.00         1      4.60           5  Free   0.00       Everyone
# ...       ...       ...       ...         ...   ...    ...            ...
# 10824    4.40   2731171      4.00  1000000000  Free   0.00       Everyone
# 10828    4.30  25655305      4.65  1000000000  Free   0.00           Teen
# 10829    3.70    906384      4.65  1000000000  Free   0.00           Teen
# 10831    3.90    877635     13.00  1000000000  Free   0.00           Teen
# 10835    4.50  27722264     76.00  1000000000  Free   0.00   Everyone 10+
#
#                         Genres         Android_Ver
# 21                     Medical        4.0.3 and up
# 28                      Arcade          2.3 and up
# 47                      Arcade          2.3 and up
# 82                      Arcade          4.1 and up
# 99                     Medical          4.0 and up
# ...                        ...                 ...
# 10824             Productivity  Varies with device
# 10828  Video Players & Editors  Varies with device
# 10829  Video Players & Editors  Varies with device
# 10831         News & Magazines          4.4 and up
# 10835                   Arcade          4.1 and up
#
# [8197 rows x 11 columns]

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_clean['Revenue_Estimate'] = df_apps_clean['Price'] * df_apps_clean['Installs']
# Out:
# /var/folders/pm/947130td48b2yff02y1061940000gn/T/ipykernel_68708/1287560783.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_apps_clean.sort_values('Revenue_Estimate', ascending=False).head(10)
# Out:
#                                 App     Category  Rating  Reviews  Size_MBs  \
# 9220                      Minecraft       FAMILY    4.50  2376564     19.00
# 8825                  Hitman Sniper         GAME    4.60   408292     29.00
# 7151  Grand Theft Auto: San Andreas         GAME    4.40   348962     26.00
# 7477            Facetune - For Free  PHOTOGRAPHY    4.40    49553     48.00
# 7977        Sleep as Android Unlock    LIFESTYLE    4.50    23966      0.85
# 6594            DraStic DS Emulator         GAME    4.60    87766     12.00
# 6082                   Weather Live      WEATHER    4.50    76593      4.75
# 7044                         Tasker        TOOLS    4.60    43045      3.40
# 7954                    Bloons TD 5       FAMILY    4.60   190086     94.00
# 7633        Five Nights at Freddy's         GAME    4.60   100805     50.00
#
#       Installs  Type  Price Content_Rating                     Genres  \
# 9220  10000000  Paid   6.99   Everyone 10+  Arcade;Action & Adventure
# 8825  10000000  Paid   0.99     Mature 17+                     Action
# 7151   1000000  Paid   6.99     Mature 17+                     Action
# 7477   1000000  Paid   5.99       Everyone                Photography
# 7977   1000000  Paid   5.99       Everyone                  Lifestyle
# 6594   1000000  Paid   4.99       Everyone                     Action
# 6082    500000  Paid   5.99       Everyone                    Weather
# 7044   1000000  Paid   2.99       Everyone                      Tools
# 7954   1000000  Paid   2.99       Everyone                   Strategy
# 7633   1000000  Paid   2.99           Teen                     Action
#
#              Android_Ver  Revenue_Estimate
# 9220  Varies with device     69,900,000.00
# 8825          4.1 and up      9,900,000.00
# 7151          3.0 and up      6,990,000.00
# 7477          4.1 and up      5,990,000.00
# 7977          4.0 and up      5,990,000.00
# 6594          2.3 and up      4,990,000.00
# 6082  Varies with device      2,995,000.00
# 7044  Varies with device      2,990,000.00
# 7954        2.3.3 and up      2,990,000.00
# 7633          2.3 and up      2,990,000.00

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df_apps_clean.Category.nunique()
# Out:
# 33

# %%
top10_category = df_apps_clean.Category.value_counts()[:10]
top10_category
# Out:
# Category
# FAMILY             1608
# GAME                914
# TOOLS               721
# PRODUCTIVITY        301
# LIFESTYLE           297
# FINANCE             296
# PERSONALIZATION     296
# MEDICAL             293
# PHOTOGRAPHY         265
# BUSINESS            263
# Name: count, dtype: int64

# %%
bar = px.bar(x = top10_category.index, # index = category name
             y = top10_category.values)
 
bar.show()

# %%
category_installs = df_apps_clean.groupby('Category').agg({'Installs': pd.Series.sum})
category_installs.sort_values('Installs', ascending=True)
# Out:
#                         Installs
# Category
# EVENTS                  15949410
# BEAUTY                  26916200
# PARENTING               31116110
# MEDICAL                 39262676
# COMICS                  44931100
# LIBRARIES_AND_DEMO      52083000
# AUTO_AND_VEHICLES       53129800
# HOUSE_AND_HOME          97082000
# ART_AND_DESIGN         114233100
# DATING                 140912410
# FOOD_AND_DRINK         211777750
# EDUCATION              352852000
# WEATHER                361096500
# FINANCE                455249400
# MAPS_AND_NAVIGATION    503267560
# LIFESTYLE              503611120
# BUSINESS               697018120
# SPORTS                1096431465
# HEALTH_AND_FITNESS    1144006220
# SHOPPING              1410331540
# PERSONALIZATION       1532341930
# BOOKS_AND_REFERENCE   1665791655
# ENTERTAINMENT         2113660000
# NEWS_AND_MAGAZINES    2369110650
# TRAVEL_AND_LOCAL      2894859300
# VIDEO_PLAYERS         3916897200
# FAMILY                4447554490
# PHOTOGRAPHY           4669143130
# SOCIAL                5487841475
# PRODUCTIVITY          5788070180
# TOOLS                 8110724500
# COMMUNICATION        11039241530
# GAME                 13973762717

# %%
h_bar = px.bar(x = category_installs.Installs,
               y = category_installs.index,
               orientation='h',
               title='Category Popularity')
 
h_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category')
h_bar.show()

# %%
category_installs['App'] = df_apps_clean.groupby('Category').agg({'App': pd.Series.count})

# %%
fig = px.scatter(category_installs, x=category_installs.App, y=category_installs.Installs, title='Category Concetration', color='Installs', 
                 size='App', hover_name=category_installs.index )

fig.update_layout(
    xaxis_title='Number of Apps (Lower=More Concentrated)',
    yaxis_title='Installs',
    yaxis=dict(type='log')
)

fig.show()

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
df_apps_clean.Genres.nunique()
# Out:
# 115

# %%
stack = df_apps_clean.Genres.str.split(';', expand=True).stack()
print(f'We now have a single column with shape: {stack.shape}')
# Out:
# We now have a single column with shape: (8578,)

# %%
num_genres = stack.value_counts()
print(f'Number of genres: {len(num_genres)}')
# Out:
# Number of genres: 53

# %%
num_genres
# Out:
# Tools                      721
# Education                  588
# Entertainment              498
# Action                     304
# Productivity               301
# Lifestyle                  298
# Personalization            296
# Finance                    296
# Medical                    293
# Sports                     270
# Photography                265
# Business                   263
# Communication              258
# Health & Fitness           246
# Casual                     216
# News & Magazines           204
# Social                     203
# Simulation                 200
# Travel & Local             187
# Arcade                     186
# Shopping                   181
# Books & Reference          171
# Video Players & Editors    151
# Dating                     134
# Puzzle                     124
# Maps & Navigation          118
# Role Playing               111
# Racing                     103
# Action & Adventure          96
# Strategy                    95
# Food & Drink                95
# Educational                 93
# Adventure                   78
# Auto & Vehicles             73
# Weather                     72
# Pretend Play                68
# Brain Games                 65
# Libraries & Demo            64
# Art & Design                62
# House & Home                62
# Board                       58
# Comics                      54
# Parenting                   50
# Card                        47
# Events                      45
# Beauty                      42
# Casino                      37
# Creativity                  32
# Music & Video               31
# Trivia                      28
# Word                        23
# Music                       21
# Music & Audio                1
# Name: count, dtype: int64

# %%
df_apps_clean.Type.value_counts()
# Out:
# Type
# Free    7609
# Paid     588
# Name: count, dtype: int64

# %%
df_free_vs_paid = df_apps_clean.groupby(["Category", "Type"], as_index=False).agg({'App': pd.Series.count})
df_free_vs_paid.head()
# Out:
#             Category  Type  App
# 0     ART_AND_DESIGN  Free   58
# 1     ART_AND_DESIGN  Paid    3
# 2  AUTO_AND_VEHICLES  Free   72
# 3  AUTO_AND_VEHICLES  Paid    1
# 4             BEAUTY  Free   42

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
df_apps_clean.head()
# Out:
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL    5.00        4
# 28                                         Ra Ga Ba     GAME    5.00        2
# 47                                          Mu.F.O.     GAME    5.00        2
# 82                                 Brick Breaker BR     GAME    5.00        7
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00        1
#
#     Size_MBs  Installs  Type  Price Content_Rating   Genres   Android_Ver  \
# 21     25.00         1  Free   0.00       Everyone  Medical  4.0.3 and up
# 28     20.00         1  Paid   1.49       Everyone   Arcade    2.3 and up
# 47     16.00         1  Paid   0.99       Everyone   Arcade    2.3 and up
# 82     19.00         5  Free   0.00       Everyone   Arcade    4.1 and up
# 99      4.60         5  Free   0.00       Everyone  Medical    4.0 and up
#
#     Revenue_Estimate
# 21              0.00
# 28              1.49
# 47              0.99
# 82              0.00
# 99              0.00

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
fig = px.bar(num_genres, x=num_genres.index[:15], y=num_genres.values[:15], title='Top Genres', color=num_genres.values[:15], 
              hover_name=num_genres.index[:15], color_continuous_scale='Agsunset')

fig.update_layout(
    xaxis_title='Genre',
    yaxis_title='Number of Apps', 
    coloraxis_showscale=False
)

fig.show()

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
fig = px.bar(df_free_vs_paid, x=df_free_vs_paid.Category, y=df_free_vs_paid.App, color='Type',
            barmode='group', title='Paid vs Free Apps')

fig.update_layout(xaxis_title='Category',
                    yaxis_title='Number of Apps',
                    xaxis={'categoryorder':'total descending'},
                    yaxis=dict(type='log'))

fig.show()

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
box = px.box(df_apps_clean, x=df_apps_clean.Type, y=df_apps_clean.Installs, color='Type', 
             title='How Many Downloads are Paid Apps Giving Up?', notched=True, points='all')


box.update_layout(yaxis=dict(type='log'))


box.show()

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']
box = px.box(df_paid_apps, x='Category', y='Installs', title='How much can Apps earn?')

box.update_layout(yaxis=dict(type='log'), 
                  yaxis_title='Paid Apps Ballpark Review', 
                  xaxis={'categoryorder':'min ascending'})

box.show()

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
box = px.box(df_paid_apps, x='Category', y='Price', title='Price per Category')

box.update_layout(yaxis=dict(type='log'), 
                  yaxis_title='Paid App Price', 
                  xaxis={'categoryorder':'max ascending'})

box.show()

# %%
df_paid_apps.Price.median()
# Out:
# 2.99
